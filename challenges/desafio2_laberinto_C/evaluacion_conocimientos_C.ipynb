# %% [markdown]
# <a href="https://colab.research.google.com/github/NanoBurgos/Penguin_Academy/blob/main/challenges/desafio2_laberinto_C/evaluacion_conocimientos_C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Te preparo una lista de preguntas estilo profesor que apuntan a comprobar si realmente entendiste tu código.**

# %% [markdown]
# ¿Qué diferencia hay entre las constantes #define PAREDES, CAMINOS y SOLUCION y por qué se usan?
#
# ¿Qué hace exactamente la macro #define IDX(f, c) ((f) * tablero_columnas + (c)) y por qué es necesaria?
#
# ¿Por qué laberinto se declara como char *laberinto en lugar de char laberinto[][]?
#
# ¿Qué propósito tiene la función clear_screen() y cómo maneja la portabilidad entre Linux y Windows?
#
# ¿Qué diferencia existe entre Sleep(ms) en Windows y usleep(ms * 1000) en Linux?
#
# ¿Qué hace la función laberinto_inicial() y por qué se inicializa todo con paredes antes de generar caminos?
#
# ¿Por qué en crear_laberinto() se mueven en saltos de 2 celdas ({0,2},{0,-2},{2,0},{-2,0}) en lugar de 1?
#
# ¿Qué rol cumple la recursividad en la función crear_laberinto()?
#
# ¿Qué efecto tiene la línea mostrar_laberinto(-1, -1); dentro de crear_laberinto()?
#
# ¿Cómo se implementa la cola en la función resolver_laberinto_bfs() y por qué es necesaria para BFS?
#
# ¿Por qué al recorrer la ruta encontrada con BFS se marca con SOLUCION ('*') en lugar de '.'?
#
# ¿Cuál es la diferencia entre mostrar_laberinto() y mostrar_jugador_laberinto()?
#
# ¿Qué validaciones se hacen en main() para garantizar que las dimensiones del laberinto sean correctas?
#
# ¿Qué pasa si el usuario ingresa dimensiones menores a 2x2?
#
# ¿Por qué se calcula tablero_filas = filas * 2 + 1 y no simplemente filas?
#
# ¿Cuál es la diferencia entre elegir la opción 1. Jugar y la opción 2. Ver animación de resolución?
#
# ¿Qué mide la variable tiempo_transc_gen_laberinto y cómo se calcula?
#
# ¿Por qué es importante liberar la memoria con free(laberinto) al final del programa?

# %% [markdown]
# # **Te hago preguntas nuevas, pero esta vez subimos un poco el nivel: habrá más sobre eficiencia, punteros, estructuras de datos, portabilidad y posibles errores.**

# %% [markdown]
# ¿Por qué se usa srand(time(NULL)) en main() antes de crear el laberinto?
#
# ¿Qué pasaría si no se mezclaran aleatoriamente las direcciones en crear_laberinto()?
#
# ¿Por qué el jugador comienza en (1,0) y no en (0,0)?
#
# ¿Qué función cumple la condición laberinto[IDX(nf,nc)] == PAREDES en la generación recursiva del laberinto?
#
# ¿Qué problema podría surgir si no se usara malloc para reservar memoria del laberinto?
#
# ¿Qué pasaría si olvidas llamar a free(laberinto) al final del programa?
#
# ¿Por qué en juego_usuario() se guarda la posición recorrida con '.' y no con '*'?
#
# ¿Qué significa scanf("%c", &eleccion_usuario);
#
# ¿Qué diferencia hay entre usar clock() y time(NULL) para medir tiempos en tu programa?
#
#
# ¿Qué representa el arreglo int direcciones[4][2] = {{1,0},{-1,0},{0,1},{0,-1}}; dentro de BFS?
#
# ¿Qué ocurre si el laberinto generado no tiene un camino válido entre entrada y salida?
#
# ¿Por qué en mostrar_laberinto() se pasa -1, -1 cuando no hay jugador que mostrar?
#
# ¿Qué riesgo tiene usar system("cls") o system("clear") en términos de seguridad?
#
# ¿Qué ventaja tiene implementar el laberinto en un arreglo 1D (char *laberinto) en lugar de un 2D (char laberinto[][])?
#
# ¿Cómo evita el código que el jugador se mueva fuera de los límites del tablero?
#
# ¿Qué pasaría si el usuario escribe una tecla diferente de w, a, s o d?
