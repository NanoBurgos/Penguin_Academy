# %% [markdown]
# <a href="https://colab.research.google.com/github/NanoBurgos/Penguin_Academy/blob/main/challenges/desafio3_escape_coordenadas/evaluacion_conocimientos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Te preparo una lista de 20 preguntas estilo profesor que apuntan a comprobar si realmente entendiste tu código. Están ordenadas más o menos por secciones (interfaz, lógica del tablero, algoritmo A*, funciones adicionales, etc.).

# %% [markdown]
# # Preguntas sobre la interfaz y variables
#
# ¿Para qué sirve la variable tamano_celda_px en el programa?
#
# ¿Qué función cumple el canvas en Tkinter dentro de este código?
#
# ¿Por qué se utiliza ventana.after(5000, ...) y no time.sleep(5)?
#
# ¿Cuál es la diferencia entre Label, Entry y Button en este programa?
#
# ¿Qué pasaría si no se llama a ventana.mainloop() al final?

# %% [markdown]
# # Preguntas sobre el tablero
#
# ¿Qué estructura de datos se usa para representar el tablero y por qué?
#
# ¿Qué significan los valores 0, 1, 2, 3 en el tablero?
#
# ¿Cómo hace el programa para que los bloques temporales desaparezcan solos?
#
# ¿Qué sucede si hago clic en la celda donde está el inicio o la meta?
#
# ¿Qué hace la función celda_valida y por qué es importante?

# %% [markdown]
# # Preguntas sobre dibujo y visualización
#
# En dibujar_tablero, ¿por qué se usa un diccionario colores?
#
# ¿Cómo se pintan el inicio y la meta de manera diferente al resto del tablero?
#
# ¿Qué ocurre visualmente cuando se encuentra una ruta con A*?

# %% [markdown]
# # Preguntas sobre el algoritmo A*
#
# ¿Cuál es la diferencia entre la lista abiertos y el diccionario camino_previo?
#
# ¿Por qué se usa float("inf") en las matrices costos y puntajes?
#
# ¿Qué hace la función heuristica y por qué se usa la distancia de Manhattan?
#
# Explica qué significa la línea:
#
#     abiertos.sort(key=lambda cel: puntajes[cel[0]][cel[1]])
#
# ¿Qué diferencia hay entre costos y puntajes dentro del algoritmo A*?
#
# ¿Cómo se reconstruye la ruta una vez que se llega a la meta?
#
# ¿Qué mensaje se muestra si no hay ruta posible y en qué parte del código ocurre?
