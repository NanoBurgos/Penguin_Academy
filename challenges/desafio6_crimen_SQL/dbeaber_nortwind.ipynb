# %% [markdown]
# # **NIVEL 1 — SELECT BÁSICO**
#
# 🧪 Ejercicio 1
#
# - Mostrá todos los clientes.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 🧪 Ejercicio 2
#
# Mostrá solo:
#
# - CustomerName
#
# - Country
#
# de la tabla Customers.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 🧪 Ejercicio 3
#
# Mostrá los productos con:
#
# - ProductName
#
# - Price
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # **🔹 NIVEL 1.2 — WHERE (filtros)**
#
# 🧪 Ejercicio 4
#
# - Mostrá los clientes que sean de Germany.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 🧪 Ejercicio 5
#
# - Mostrá los productos con precio mayor a 50.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 🧪 Ejercicio 6
#
# - Mostrá los productos que no estén discontinuados.
#
# 💡 Pista: mirá la columna Discontinued.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # **🔹 NIVEL 1.3 — ORDER BY + LIMIT**
#
# 🧪 Ejercicio 7
#
# - Mostrá los 5 productos más caros.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 🧪 Ejercicio 8
#
# - Mostrá los 10 clientes ordenados por nombre (A–Z).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # **🔹 NIVEL 1.4 — AND / OR**
#
# 🧪 Ejercicio 9
#
# Mostrá los productos:
#
# - Precio mayor a 20
#
# - Que no estén discontinuados
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 🧪 Ejercicio 10
#
# Mostrá los clientes que sean de:
#
# - Germany
#
# - OR France
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # **🔗 NIVEL 2 — JOINs (desde cero)**
#
# 🧠 IDEA CLAVE (antes de escribir SQL)
#
# Un JOIN sirve para unir filas de dos tablas relacionadas usando una clave.
#
# En Northwind, las relaciones más importantes son:
#
# - Customers.CustomerID ↔ Orders.CustomerID
#
# - Orders.OrderID ↔ OrderDetails.OrderID
#
# - Products.ProductID ↔ OrderDetails.ProductID
#
# - Products.CategoryID ↔ Categories.CategoryID
#
# **👉 Regla de oro:**
#
# Un JOIN siempre une una PK (Primary Key) con una FK (Foreign Key).

# %% [markdown]
# # **🔹 INNER JOIN (el más usado)**
#
# Un INNER JOIN devuelve solo los registros que existen en ambas tablas.

# %% [markdown]
# 🧪 Ejercicio 11
#
# Mostrá:
#
# - Nombre del cliente
#
# - ID del pedido
#
# ✍️ Pensá:
#
# - Cliente → Customers
#
# - Pedido → Orders
#
# ¿Qué columna los conecta?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 🧪 Ejercicio 12
#
# Mostrá:
#
# - Cliente
#
# - Fecha del pedido
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # **🔹 JOIN + WHERE**
#
# 🧪 Ejercicio 13
#
# Mostrá los pedidos hechos por clientes de Germany.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # **🔹 JOIN de 3 tablas**
#
# Acá es donde SQL empieza a valer oro.
#
# 🧪 Ejercicio 14
#
# Mostrá:
#
# - Cliente
#
# - Pedido
#
# - Producto
#
# ✍️ Pensá la cadena:
#
# Customers → Orders → OrderDetails → Products
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # **🔹 JOIN + AGREGACIONES**
#
# 🧪 Ejercicio 15
#
# - Mostrá cuántos pedidos hizo cada cliente.
#
# ![image.png](attachment:image.png)
#
# De esta forma podemos ver que una misma persona realizo varios pedidos, entonces debemos de agrupar esos pedidos en una nueva variable
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 🧪 Ejercicio 16
#
# - Mostrá el total de dinero vendido por pedido.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # **🔹 LEFT JOIN (muy importante)**
#
# Un **LEFT JOIN** devuelve:
#
# - Todo lo de la tabla izquierda
#
# - Aunque no tenga coincidencia en la derecha

# %% [markdown]
# 🧪 Ejercicio 17
#
# - Mostrá todos los clientes, incluso los que nunca hicieron pedidos.
#
# ![image.png](attachment:image.png)
#
# Un cliente que nunca hizo pedido, podria aparecer en la tabla con OrderID = NULL
#
# En Esta BD, todos los clientes realizaron pedidos alguna vez

# %% [markdown]
# # **🧠 DIFERENCIA CLAVE**
#
# |JOIN	|Qué devuelve|
# |:-:|:-:|
# |INNER JOIN	|Solo coincidencias|
# |LEFT JOIN	|Todo lo de la izquierda|
# |RIGHT JOIN	|SQLite NO lo soporta|
# |FULL JOIN	|SQLite NO lo soporta|

# %% [markdown]
# # **Ejercicios con Consultas Reales de Negocios**
#
# Las consultas reales de negocio son las que se usan en empresas para tomar decisiones, no para aprobar exámenes.
# A partir de acá vas a pensar como analista de datos / backend / BI.
#
# Vamos a trabajar con preguntas reales, y para cada una:
#
# - Planteo del problema (mentalidad negocio)
#
# - Ejercicio
#
# - Consulta correcta
#
# - Qué información aporta

# %% [markdown]
# # **🧠 CASO 1 — ¿Quiénes son mis mejores clientes?**
#
# 🎯 Pregunta de negocio
#
# ¿Qué clientes generan más dinero?
#
# 🧪 Ejercicio 1
#
# Mostrá:
#
# - Cliente
#
# - Total gastado
#
# Ordenado de mayor a menor.
#
# ![image.png](attachment:image.png)
#
# **¿Que informacion aporta?**
#
# - Identificar clientes VIP
#
# - Priorizar descuentos o atención premium

# %% [markdown]
# # **🧠 CASO 2 — Productos más vendidos**
#
# 🎯 Pregunta de negocio
#
# ¿Qué productos se venden más (en unidades)?
#
# 🧪 Ejercicio 2
#
# Mostrá:
#
# - Producto
#
# - Total de unidades vendidas
#
# ![image.png](attachment:image.png)
#
# **¿Que informacion aporta?**
#
# - Informacion para optimizar stock
#
# - Informacion para detectar productos estrella

# %% [markdown]
# # **🧠 CASO 3 — Ingresos por categoría**
#
# 🎯 Pregunta de negocio
#
# ¿Qué categorías generan más ingresos?
#
# 🧪 Ejercicio 3
#
# Mostrá:
#
# - Categoría
#
# - Total vendido
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # **🧠 CASO 4 — Ventas por país**
#
# 🎯 Pregunta de negocio
#
# ¿En qué países vendo más?
#
# 🧪 Ejercicio 4
#
# Mostrá:
#
# - País
#
# - Total vendido
#
# ![image.png](attachment:image.png)
